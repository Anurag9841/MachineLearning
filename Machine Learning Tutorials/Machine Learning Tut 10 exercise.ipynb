# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
for i in range(10):
    plt.matshow(digits.images[i])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.3)

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)
# Out:
# 0.9888888888888889

# %%
model1=SVC(gamma=0.5)
model1.fit(X_train,y_train)
# Out:
# SVC(gamma=0.5)

# %%
model.score(X_test,y_test)
# Out:
# 0.9888888888888889

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test
# Out:
# array([4, 6, 5, 4, 5, 7, 5, 0, 4, 8, 3, 3, 9, 7, 2, 5, 5, 0, 1, 2, 8, 7,
#        4, 0, 3, 9, 8, 6, 1, 0, 5, 9, 9, 4, 8, 2, 5, 4, 7, 7, 5, 1, 2, 4,
#        0, 7, 7, 7, 0, 5, 7, 8, 5, 5, 1, 9, 8, 7, 6, 5, 2, 7, 0, 1, 2, 5,
#        8, 7, 1, 2, 4, 4, 1, 2, 5, 6, 8, 6, 4, 2, 0, 2, 1, 9, 7, 3, 9, 5,
#        4, 3, 9, 7, 6, 5, 1, 8, 8, 6, 9, 6, 0, 9, 6, 7, 1, 4, 5, 9, 0, 6,
#        8, 5, 3, 0, 8, 2, 9, 1, 6, 7, 8, 6, 9, 8, 8, 4, 2, 8, 0, 6, 0, 7,
#        5, 2, 1, 7, 6, 8, 0, 5, 1, 4, 9, 1, 1, 5, 6, 0, 8, 5, 0, 8, 0, 4,
#        9, 3, 5, 6, 7, 4, 6, 2, 8, 4, 9, 1, 9, 4, 7, 2, 2, 1, 7, 0, 1, 1,
#        0, 0, 1, 3, 8, 6, 8, 5, 7, 1, 9, 9, 9, 2, 7, 3, 7, 4, 0, 4, 4, 0,
#        6, 6, 5, 5, 6, 0, 1, 3, 8, 6, 3, 9, 3, 1, 5, 9, 3, 4, 1, 3, 6, 5,
#        9, 3, 0, 7, 9, 3, 2, 5, 0, 8, 1, 6, 3, 2, 4, 7, 6, 0, 5, 0, 1, 8,
#        4, 4, 4, 3, 1, 1, 3, 0, 2, 1, 1, 5, 1, 6, 4, 1, 9, 0, 4, 1, 6, 1,
#        9, 9, 4, 5, 4, 9, 2, 8, 2, 3, 1, 2, 1, 2, 7, 2, 6, 0, 1, 3, 0, 9,
#        5, 2, 3, 1, 7, 8, 1, 8, 3, 5, 0, 1, 0, 2, 6, 7, 1, 1, 2, 5, 6, 5,
#        4, 7, 2, 7, 6, 8, 2, 7, 8, 7, 4, 4, 0, 6, 6, 9, 1, 6, 3, 0, 8, 8,
#        9, 2, 1, 9, 4, 0, 4, 9, 0, 4, 4, 9, 2, 2, 1, 5, 8, 7, 2, 9, 6, 8,
#        3, 3, 5, 0, 0, 0, 6, 4, 6, 4, 2, 9, 0, 8, 1, 2, 3, 4, 6, 0, 5, 3,
#        7, 2, 0, 8, 1, 3, 2, 6, 5, 3, 5, 5, 1, 5, 1, 2, 5, 4, 4, 0, 6, 8,
#        7, 6, 5, 3, 8, 9, 0, 4, 9, 9, 6, 3, 9, 7, 2, 5, 5, 2, 5, 2, 6, 3,
#        4, 7, 7, 0, 1, 4, 4, 0, 1, 4, 8, 8, 4, 7, 5, 7, 1, 6, 5, 8, 0, 1,
#        5, 6, 0, 6, 7, 3, 0, 0, 3, 9, 3, 8, 8, 1, 7, 2, 4, 7, 3, 7, 2, 5,
#        6, 0, 3, 6, 1, 0, 0, 5, 9, 3, 8, 6, 2, 0, 0, 5, 8, 1, 5, 1, 3, 9,
#        5, 2, 3, 2, 7, 2, 9, 9, 0, 5, 1, 1, 6, 4, 4, 6, 9, 4, 1, 5, 8, 9,
#        6, 9, 1, 5, 7, 7, 3, 3, 8, 1, 2, 7, 5, 0, 2, 3, 7, 6, 6, 7, 5, 9,
#        3, 4, 6, 8, 0, 6, 8, 5, 1, 2, 2, 6])

# %%
y_predict=model.predict(X_test)

# %%
y_predict
# Out:
# array([4, 6, 5, 4, 5, 7, 5, 0, 4, 8, 3, 3, 9, 7, 2, 5, 5, 0, 1, 2, 8, 7,
#        4, 0, 3, 9, 8, 6, 1, 0, 5, 9, 9, 4, 8, 2, 5, 4, 7, 7, 5, 1, 2, 4,
#        0, 7, 7, 7, 0, 5, 7, 8, 5, 5, 1, 9, 8, 7, 6, 5, 2, 7, 0, 1, 2, 5,
#        8, 7, 1, 2, 4, 4, 1, 2, 5, 6, 1, 6, 4, 2, 0, 2, 1, 9, 7, 3, 9, 5,
#        4, 3, 8, 7, 6, 5, 1, 8, 1, 6, 9, 6, 0, 9, 6, 7, 1, 4, 5, 9, 0, 6,
#        8, 5, 3, 0, 8, 2, 9, 1, 6, 7, 8, 6, 9, 8, 8, 4, 2, 8, 0, 6, 0, 7,
#        5, 2, 1, 7, 6, 8, 0, 5, 1, 4, 9, 1, 1, 5, 6, 0, 8, 5, 0, 8, 0, 4,
#        9, 3, 5, 6, 7, 4, 6, 2, 8, 4, 9, 1, 9, 4, 7, 2, 2, 1, 7, 0, 1, 1,
#        0, 0, 1, 3, 8, 6, 8, 5, 7, 1, 9, 9, 9, 2, 7, 3, 7, 4, 0, 4, 4, 0,
#        6, 6, 5, 5, 6, 0, 1, 3, 8, 6, 3, 9, 3, 1, 5, 9, 3, 4, 1, 3, 6, 5,
#        9, 3, 0, 7, 9, 3, 2, 5, 0, 8, 1, 6, 3, 2, 4, 7, 6, 0, 5, 0, 1, 8,
#        4, 4, 4, 3, 1, 1, 3, 0, 2, 1, 1, 5, 1, 6, 4, 1, 9, 0, 4, 1, 6, 1,
#        9, 9, 4, 5, 4, 9, 2, 8, 2, 3, 1, 2, 1, 2, 7, 2, 6, 0, 1, 3, 0, 9,
#        5, 2, 3, 1, 7, 8, 1, 8, 3, 5, 0, 1, 0, 2, 6, 7, 1, 1, 2, 5, 6, 5,
#        4, 7, 2, 7, 6, 8, 2, 7, 8, 7, 4, 4, 0, 6, 6, 9, 1, 6, 3, 0, 8, 1,
#        9, 2, 1, 9, 4, 0, 4, 9, 0, 4, 4, 9, 2, 2, 1, 5, 8, 7, 2, 9, 6, 8,
#        3, 3, 5, 0, 0, 0, 6, 4, 6, 4, 2, 9, 0, 8, 1, 2, 3, 4, 6, 0, 5, 3,
#        7, 2, 0, 8, 1, 3, 2, 6, 5, 3, 5, 5, 1, 5, 1, 2, 5, 4, 4, 0, 6, 8,
#        7, 6, 5, 3, 8, 9, 0, 4, 9, 9, 6, 3, 9, 7, 2, 5, 5, 2, 5, 2, 8, 3,
#        4, 7, 7, 0, 1, 4, 4, 0, 1, 4, 8, 8, 4, 7, 5, 7, 1, 6, 5, 8, 0, 1,
#        5, 6, 0, 6, 7, 3, 0, 0, 3, 9, 3, 8, 8, 1, 7, 2, 4, 7, 3, 7, 2, 5,
#        6, 0, 3, 6, 1, 0, 0, 5, 9, 3, 1, 6, 2, 0, 0, 5, 8, 1, 5, 1, 3, 9,
#        5, 2, 3, 2, 7, 2, 9, 9, 0, 5, 1, 1, 6, 4, 4, 6, 9, 4, 1, 5, 8, 9,
#        6, 9, 1, 5, 7, 7, 3, 3, 8, 1, 2, 7, 5, 0, 2, 3, 7, 6, 6, 7, 5, 9,
#        3, 4, 6, 8, 0, 6, 8, 5, 1, 2, 2, 6])

# %%
cm=confusion_matrix(y_test,y_predict)

# %%
import seaborn as sm

# %%
sm.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>
